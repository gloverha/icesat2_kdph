# %%
import pandas as pd
import numpy as np
import glob
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from scipy import stats

# %cd -q '/Users/hglover/Library/CloudStorage/Box-Box/HannahGlover/Research/data'

# %%
def ooi_kd_calc(df):
    # pull out depth and par (log for calculation)
    z = np.abs(df['z'].to_numpy())
    par = df['par'].to_numpy()
    par[(par<=0) | np.isnan(par)] = 1

    # only calculate over upper 10m
    par = par[z<10]
    z = z[z<10]

    
    # sort by depth correctly
#     par = par[np.argsort(z)]
#     z = z[np.argsort(z)]
    
    # calc ln of par 
    par = np.log(par)
    # calculate Kd from the log-linear slope of the light decay
    fit = stats.linregress(x=z,y=par)
    par_pred = fit.slope*z + par[0]
    kd = np.abs(fit.slope)
    rval = fit.rvalue
    stderr=np.exp(fit.stderr)

    return kd,rval,stderr

# %%
# calculate Kd from OOI data


FF = glob.glob('icesat2/ooi/data*.csv')
FF.sort()

ooi_kd_array = pd.DataFrame(data=None,
                            index=range(len(FF)),
                            columns=['time','lat','lon','kd','rval','stderr','stn']
                           )

for jj in range(len(FF)):
    df = pd.read_csv(FF[jj],
                     index_col=0,
                     header=0,
                     usecols=[i for i in range(6)],
                     names=['', 'time', 'lat', 'lon', 'z', 'par']
                    ) #
    ooi_kd_array.loc[jj,'stn'] = FF[jj][9:-4]
    
    try:
        kd,rval,stderr = ooi_kd_calc(df)
    except:
        kd = np.nan
        rval = np.nan
        stderr = np.nan

    time = df.loc[1,'time']
    lat = df.loc[1,'lat']
    lon = df.loc[1,'lon']

    ooi_kd_array.loc[jj,'time'] = time
    ooi_kd_array.loc[jj,'lat'] = lat
    ooi_kd_array.loc[jj,'lon'] = lon
    ooi_kd_array.loc[jj,'kd'] = kd
    ooi_kd_array.loc[jj,'rval'] = rval
    ooi_kd_array.loc[jj,'stderr'] = stderr


# pd.DataFrame()
# d = {'time' = ff[0,1],'kd': m, 'rval': rval, 'stderr': stderr}
# df = pd.DataFrame(data=d)

ooi_kd_array.to_csv('../output/icesat2/ooi_kdcalculations10m.csv')
ooi_kd_array
# Out:
#                     time        lat         lon        kd      rval    stderr  \
# 0   2019-06-03T13:59:00Z    44.6589  -124.09595  0.223742 -0.996769  1.006838
# 1   2019-08-06T20:00:00Z    44.6589  -124.09595  0.511778 -0.978991  1.038405
# 2   2021-08-28T20:06:00Z    44.6589  -124.09595  0.252001 -0.991579  1.011704
# 3   2022-07-02T20:07:00Z    44.6589  -124.09595  0.613939 -0.990809  1.032187
# 4   2019-10-07T20:13:00Z   44.63302  -124.30233  0.216985  -0.99827  1.004529
# 5   2023-05-30T12:04:00Z  44.369353 -124.954108       NaN       NaN       NaN
# 6   2024-08-26T14:21:00Z  44.369353 -124.954108  0.062013   -0.0911  1.134146
# 7   2019-09-08T20:03:00Z   47.13553  -124.27017  0.276693 -0.999271  1.004004
# 8   2021-06-27T23:32:00Z   47.13553  -124.27017  0.224815 -0.998742  1.004275
# 9   2019-06-14T01:31:00Z   46.85262  -124.98263       NaN       NaN       NaN
# 10  2020-09-09T23:44:00Z   46.85262  -124.98263       NaN       NaN       NaN
# 11  2022-03-09T01:09:00Z   46.85262  -124.98263       NaN       NaN       NaN
# 12  2022-03-31T11:43:00Z   46.85262  -124.98263       NaN       NaN       NaN
# 13  2023-03-29T17:10:00Z   46.85262  -124.98263       NaN       NaN       NaN
#
oi/data_ooi-rs01sbps-sf01a-3c-parada101_2021-0...
# 43  oi/data_ooi-rs01sbps-sf01a-3c-parada101_2022-0...
# 44  oi/data_ooi-rs01sbps-sf01a-3c-parada101_2023-0...
# 45  oi/data_ooi-rs01sbps-sf01a-3c-parada101_2023-1...
# 46  oi/data_ooi-rs01sbps-sf01a-3c-parada101_2023-1...
# 47  oi/data_ooi-rs01sbps-sf01a-3c-parada101_2024-0...
# 48  oi/data_ooi-rs03axps-sf03a-3c-parada301_2021-0...
# 49  oi/data_ooi-rs03axps-sf03a-3c-parada301_2021-0...
# 50  oi/data_ooi-rs03axps-sf03a-3c-parada301_2023-0...
# 51  oi/data_ooi-rs03axps-sf03a-3c-parada301_2023-0...
# 52  oi/data_ooi-rs03axps-sf03a-3c-parada301_2023-0...

# %%
# calculate kd for all of gulf of mexico ctd profiles 
FF = glob.glob('icesat2/ctd_ws/data*.csv')
FF.sort()

ws_kd_array = pd.DataFrame(data=None,
                            index=range(len(FF)),
                            columns=['time','lat','lon','kd','rval','stderr','stn']
                           )

for jj in range(len(FF)):
    df = pd.read_csv(FF[jj],
                     index_col=0,
                     header=0,
                     usecols=[i for i in [0,2,3,4,5,6,28]],
                     names=['','prof', 'time', 'lat', 'lon', 'z', 'par']
                    )
    ws_kd_array.loc[jj,'stn'] = FF[jj][12:-4]
    
    try:
        kd,rval,stderr = ooi_kd_calc(df)
    except:
        kd = np.nan
        rval = np.nan
        stderr = np.nan

    time = df.loc[1,'time']
    lat = df.loc[1,'lat']
    lon = df.loc[1,'lon']

    ws_kd_array.loc[jj,'time'] = time
    ws_kd_array.loc[jj,'lat'] = lat
    ws_kd_array.loc[jj,'lon'] = lon
    ws_kd_array.loc[jj,'kd'] = kd
    ws_kd_array.loc[jj,'rval'] = rval
    ws_kd_array.loc[jj,'stderr'] = stderr



pname = '../output/icesat2/'
ws_kd_array.to_csv(pname+'ws_kdcalculations10m.csv')
ws_kd_array
# Out:
#                    time        lat        lon        kd      rval    stderr  \
# 0  2018-12-18T08:19:41Z  24.597167 -81.181333  0.142587 -0.504765  1.007733
# 1  2020-08-20T00:54:19Z  25.404333   -82.2105  0.000843 -0.009688   1.00203
# 2  2020-10-09T09:36:26Z  26.632167   -82.5595  4.157565 -0.825658  1.070123
# 3  2022-12-06T19:31:24Z  27.796667 -82.879667  0.178231  -0.59098  1.004571
# 4  2022-12-06T20:09:35Z    27.7405 -82.928333  0.064517 -0.448053    1.0023
#
#                                        stn
# 0            ws/data_WS18351_WS18351_STA18
# 1           ws/data_WS20231_WS20231_STA_30
# 2  ws/data_WS20279_WS20279_WS20278_Stn_BG4
# 3  ws/data_WS22337_WS22337_WS22337_Stn_TB1
# 4  ws/data_WS22337_WS22337_WS22337_Stn_TB2

# %%
# Process BCODMO data : only keep unique entries to search ICESat-2
FF = glob.glob('bcodmo/*.csv')
FF.sort()

for jj in range(len(FF)):
    df = pd.read_csv(FF[jj],header=0)
    df.drop(0,inplace=True)
    df = df.drop_duplicates(subset=['time'])
    df.reset_index(drop=True, inplace=True)

    print(FF[jj])
    print(df.head())
    
    fname = FF[jj][:-4]+'_unique.pkl'
    df.to_pickle(fname)
# Out:
# bcodmo/bcodmo_dataset_518582_2e2e_e9a0_6c3e.csv
#   cast latitude  longitude depth_w                  time     par
# bcodmo/bcodmo_dataset_815732_68e0_5c4d_62dc.csv
#   Cast_ID                  time   latitude   longitude depth PAR_Irradiance
# 0       1  2015-03-16T15:56:47Z  31.032117  -76.343633   2.0         1417.0
# 1       2  2015-03-16T17:50:10Z  31.005317  -76.334083   2.0         -379.4
# 2       3  2015-03-16T19:54:54Z  31.052872  -76.597728   2.0         1350.0
# 3       4  2015-03-17T11:53:17Z   31.05692  -76.591803   3.0           54.1
# 4       5  2015-03-17T15:30:57Z  31.075522  -76.849018   2.0         1590.0
# bcodmo/bcodmo_dataset_874909_v1_8bf6_bf9e_ab56.csv
#     latitude  longitude                  time Station  depth PAR_Irradiance
# 0  -76.45435  167.91856  2018-02-11T19:19:00Z      67  0.989         838.72
# 1  -74.74383   170.3741  2018-02-13T21:25:00Z      70  0.989         4108.9
# 2  -74.80015  164.39491  2018-02-14T22:28:00Z      72  0.988         2313.2
# 3   -74.7991  164.59668  2018-02-16T20:15:00Z      76  0.963         732.07
# 4  -74.69552  164.79597  2018-02-17T20:34:00Z      78  0.989         860.87
# bcodmo/bcodmo_dataset_908342_v1_7e78_d78e_c5cc.csv
#   Station   latitude   longitude                  time        par
# 0    9001   -56.5005  -140.70284  2021-02-02T03:45:31Z     40.389
# 1    9101  -56.00383  -140.50467  2021-02-02T07:42:22Z  -0.001258
# 2    9201   -53.4965   -137.0215  2021-02-03T09:27:45Z    0.98411
# 3    9301  -53.78167  -137.52467  2021-02-03T13:03:40Z    1.0E-12
# 4    9401  -54.07917   -138.0225  2021-02-03T16:28:53Z     105.03
# bcodmo/bcodmo_dataset_915709_v1_1cbb_6b39_1f21.csv
#   CTD_Cast      Par  latitude  longitude                  time
# 0        1  1.0E-12   42.4245  -69.75144  2021-08-04T04:48:02Z
# 1        1  1.0E-12  42.42576  -69.75328  2021-08-04T04:41:36Z
# 2        1  1.0E-12   42.4259  -69.75348  2021-08-04T04:40:54Z
# 3        1  1.0E-12  42.42618  -69.75387  2021-08-04T04:39:34Z
# 4        1  1.0E-12  42.42645  -69.75429  2021-08-04T04:38:14Z

# %%
# Process BCODMO data
FF = glob.glob('bcodmo/*.csv')
FF.sort()

# ws_kd_array = pd.DataFrame(data=None,
#                             index=range(len(FF)),
#                             columns=['time','lat','lon','kd','rval','stderr','stn']
#                            )
jj = 1

df = pd.read_csv(FF[jj],
                 header=0)
df = df.drop_duplicates(subset=['time'])
df.head()
# Out:
#      Station       Site                  time depth  \
# 0   unitless   unitless                   UTC     m
# 1        001  Shakedown  2018-05-07T17:46:00Z   3.0
# 5        001  Shakedown  2018-05-07T17:47:00Z   7.0
# 28       001  Shakedown  2018-05-07T17:48:00Z  30.0
# 54       001  Shakedown  2018-05-07T17:49:00Z  56.0
#
#                                                   Par       latitude  \
# 0   micromoles photons per square meter per second...  degrees_north
# 1                                              1460.0       11.24758
# 5                                               169.0       11.24768
# 28                                               45.1       11.24788
# 54                                               14.8       11.24816
#
#        longitude
# 0   degrees_east
# 1      -56.32338
# 5      -56.32336
# 28     -56.32324
# 54     -56.32307
